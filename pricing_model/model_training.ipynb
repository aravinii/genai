# %% [markdown]
# # Training a XGBoost model for price prediction

# %% [markdown]
# ### Importing libs and defining functions

# %%
import pandas as pd
import numpy as np
import joblib

from pathlib import Path
import sys
sys.path.append(str(Path().resolve().parent))
from real_state_agent.utils.transformers import zero_to_nan, clip_transformer

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import TransformedTargetRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import HistGradientBoostingRegressor

# %%
log_transformer = FunctionTransformer(
    np.log1p,
    feature_names_out='one-to-one'
)

# %% [markdown]
# ### Reading files

# %%
path = str(Path().resolve().parent) + '/data/available_houses_clean.csv'
df = pd.read_csv(path, index_col=0)
df.reset_index(drop=True, inplace=True)
df.rename(columns={"region_name": "neighborhood", "total_area": "area"}, inplace=True)
df.head()
# Out:
#           type neighborhood  area  bathrooms  bedrooms  iptu  parking_slots  \
# 0  Apartamento     Brooklin    48          1         1   190              1
# 1  Apartamento     Brooklin   396          2         4  1500              3
# 2  Apartamento     Brooklin    77          1         2   180              1
# 3  Apartamento     Brooklin   204          4         4  1750              4
# 4         Casa     Brooklin   300          2         3  1334              4
#
#      price
# 0   990000
# 1  3600000
# 2   767000
# 3  3650000
# 4  2125000

# %% [markdown]
# ### Preparing the file

# %%
y = df.price
X = df.drop(['price'], axis=1)
X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2,random_state=0)

categorical_cols = [col for col in X.columns if X[col].dtype == 'str']

# %% [markdown]
# ### Model

# %%
iptu_pipeline = Pipeline(steps=[
    ('zero_to_nan', FunctionTransformer(
        zero_to_nan,
        feature_names_out='one-to-one'
    )),
    ('log', FunctionTransformer(
        np.log1p,
        feature_names_out='one-to-one'
    ))
])

preprocessor = ColumnTransformer(
    transformers=[
        ('bedrooms_clip', clip_transformer(1, 4), ['bedrooms']),
        ('bathrooms_clip', clip_transformer(1, 5), ['bathrooms']),
        ('parking_clip', clip_transformer(0, 5), ['parking_slots']),
        ('log_num', log_transformer, ['area']),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols),
        ('iptu', iptu_pipeline, ['iptu'])
    ],
    remainder='passthrough'
)

model = HistGradientBoostingRegressor(
    max_iter=1000,
    max_depth=8,
    learning_rate=0.1,
    random_state=0,
    early_stopping=True
)

pipe = Pipeline(
  steps=[
    ('preprocessor', preprocessor), 
    ('model', model)
  ]
)

final_model = TransformedTargetRegressor(
    regressor=pipe,
    func=np.log1p,
    inverse_func=np.expm1
)

# %% [markdown]
# ### Results

# %%
final_model.fit(X_train, y_train)
preds = final_model.predict(X_valid)

print('MAE:', mean_absolute_error(y_valid, preds))
# Out:
# MAE: 394426.6061823446

# %% [markdown]
# ### Cross-validation

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(
    final_model,
    X_train,
    y_train,
    cv=5,
    scoring='neg_mean_absolute_error',
    n_jobs=-1
)

mae_scores = -scores

print("MAE por fold:", mae_scores)
print("MAE médio:", mae_scores.mean())
print("Std:", mae_scores.std())
# Out:
# MAE por fold: [281869.84132406 285072.32471413 300396.37432778 296927.33518446
#  293685.07843185]
# MAE médio: 291590.19079645537
# Std: 7034.064329293996

# %% [markdown]
# ### Exporting pickle

# %%
joblib.dump(final_model, 'house_price_model.joblib')
# Out:
# ['house_price_model.joblib']

# %% [markdown]
# ### Importing pickle for test purposes

# %%
production_test = joblib.load('house_price_model.joblib')

# %%
sample = pd.DataFrame([{
    "bedrooms": 3,
    "bathrooms": 2,
    "parking_slots": 1,
    "area": 85,
    "iptu": 1200,
    "neighborhood": "Pinheiros",
    "type": "Apartamento"
}])

price_pred = production_test.predict(sample)
print("Production predicted price:", price_pred[0])

price_pred = final_model.predict(sample)
print("Staging predicted price:", price_pred[0])
# Out:
# Production predicted price: 879611.4764407098
# Staging predicted price: 879611.4764407098
