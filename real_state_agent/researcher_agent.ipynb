# %% [markdown]
# ## Researcher Agent

# %% [markdown]
# #### Importing libs

# %%
from dotenv import load_dotenv
from google import genai
from google.genai import types
import os
from pathlib import Path
from IPython.display import display, Markdown, HTML

load_dotenv()
CLIENT = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))
MODEL = "gemini-2.0-flash"

# %%
def load_prompt(prompt_name: str) -> str:
    """
    Load a prompt from the prompts directory.
    """
    base_dir = Path.cwd().parent
    prompt_path = base_dir / "prompts" / f"{prompt_name}.txt"

    if not prompt_path.exists():
        raise FileNotFoundError(f"Prompt {prompt_name} not found")

    with open(prompt_path, "r", encoding="utf-8") as f:
        return f.read()

# %% [markdown]
# #### Prompt Engineering

# %%
def research_agent(target_neighborhood: str) -> str:
    """
    Runs the real estate research agent.

    The agent analyzes the investment potential of a given neighborhood
    using a predefined system prompt and returns a structured report
    highlighting positive investment factors and living characteristics.

    Args:
        target_neighborhood (str): Name of the neighborhood to analyze.

    Returns:
        str: Generated research report about the neighborhood.
    """
    system_prompt = load_prompt("researcher_agent_v1")
    response = CLIENT.models.generate_content(
        model = MODEL,
        contents=f"BAIRRO PARA ANÁLISE: {target_neighborhood}",
        config = types.GenerateContentConfig(
            system_instruction = system_prompt,
            tools=[types.Tool(google_search=types.GoogleSearch())],
            temperature=0.3
        ))
    
    return response.text

# %%
display(Markdown(research_agent("Pinheiros")))
# Out:
# Olá! Analisarei o bairro de Pinheiros em São Paulo para identificar o potencial de investimento imobiliário na região.
#
# ## Visão Geral do Bairro
#
# Pinheiros é um dos bairros mais tradicionais, vibrantes e valorizados da Zona Oeste de São Paulo. Ele combina o charme histórico com o dinamismo da vida moderna, atraindo famílias, profissionais, empreendedores e investidores. O bairro oferece uma infraestrutura completa, com fácil acesso a serviços, comércio, lazer e cultura.
#
# ## Principais Fatores de Valorização
#
# *   **Localização Estratégica:** Pinheiros está localizado próximo a importantes vias de acesso, como a Marginal Pinheiros e a Avenida Brigadeiro Faria Lima, facilitando a locomoção pela cidade. A região é equidistante da Sé, Vila Mariana, Santo Amaro e Lapa.
# *   **Mobilidade:** O bairro é servido pela Linha 4–Amarela do metrô, pela estação CPTM Hebraica–Rebouças e por ciclovias que interligam parques e centros de negócio. A mobilidade é um fator importante que eleva a demanda por moradia local.
# *   **Infraestrutura Completa:** Pinheiros oferece hospitais de ponta, escolas bilíngues, supermercados premium e centros de coworking. Calçadas largas e bem cuidadas, iluminação moderna e redes de fibra óptica criam um ambiente urbano confortável.
# *   **Cultura e Lazer:** O bairro é conhecido por sua cena cultural e gastronômica vibrante, com uma grande variedade de restaurantes, bares, cafés, galerias de arte e casas de espetáculo. A vida noturna é animada, com opções para todos os gostos.
# *   **Valorização Imobiliária:** Pinheiros registrou uma alta média de 8% no valor do metro quadrado em 2024, superando a média da capital. A valorização constante é alimentada por lançamentos de qualidade, renovação de espaços industriais e escassez de terreno disponível. Em 2025, o mercado imobiliário de luxo cresceu 238% e Pinheiros se destacou como o novo protagonista.
# *   **Proximidade com a Faria Lima:** O crescimento do eixo corporativo da Avenida Faria Lima impulsionou a valorização e trouxe novos empreendimentos residenciais e comerciais. A proximidade com a Faria Lima pode elevar o preço do metro quadrado para mais de R$ 18.000.
#
# ## Perfil de Demanda Imobiliária
#
# *   **Diversidade de Moradores:** Pinheiros atrai uma ampla variedade de moradores, trabalhadores e visitantes, o que proporciona um mercado consumidor diversificado. O bairro atende a um leque variado de perfis: desde jovens profissionais que buscam studios eficientes até famílias que desejam mais espaço e áreas de lazer completas.
# *   **Classes Social:** A população de Pinheiros é composta por pessoas das classes média-alta e alta renda, bem como estudantes universitários e jovens profissionais.
# *   **Aluguel:** O valor médio do aluguel em Pinheiros é de R$ 5.000. O aluguel de um apartamento de 2 dormitórios em prédio com área de lazer costuma variar entre R$ 5.000 e R$ 6.500 mensais.
# *   **Venda:** O valor médio para comprar um imóvel é de R$ 1 milhão. O metro quadrado para compra oscila entre R$ 12.000 e R$ 15.000, dependendo da proximidade com as principais vias ou da vista. O valor médio do m² em Pinheiros varia entre R$ 13.000 e R$ 18.000, dependendo da localização e padrão do imóvel.
#
# ## Conclusão sobre o Potencial de Investimento
#
# Pinheiros apresenta um excelente potencial de investimento imobiliário devido à sua localização estratégica, infraestrutura completa, mobilidade, vida cultural e valorização constante. O bairro atrai uma diversidade de moradores, o que garante uma demanda consistente por imóveis. A valorização imobiliária tem superado a média da capital, o que proporciona ganhos sólidos para investidores. Apesar da falta de terrenos para novos empreendimentos, a tendência é que os imóveis em Pinheiros continuem se valorizando.
#
# Espero que esta análise detalhada do bairro de Pinheiros te ajude a tomar uma decisão de investimento mais informada! Se tiver mais alguma pergunta, é só me dizer.
