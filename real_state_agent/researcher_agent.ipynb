# %% [markdown]
# ## Researcher Agent

# %% [markdown]
# #### Importing libs

# %%
from dotenv import load_dotenv
from google import genai
from google.genai import types
import os
from pathlib import Path
from IPython.display import display, Markdown, HTML

load_dotenv()
CLIENT = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))
MODEL = "gemini-2.0-flash"

# %%
def load_prompt(prompt_name: str) -> str:
    """
    Load a prompt from the prompts directory.
    """
    base_dir = Path.cwd().parent
    prompt_path = base_dir / "prompts" / f"{prompt_name}.txt"

    if not prompt_path.exists():
        raise FileNotFoundError(f"Prompt {prompt_name} not found")

    with open(prompt_path, "r", encoding="utf-8") as f:
        return f.read()

# %% [markdown]
# #### Prompt Engineering

# %%
def research_agent(target_neighborhood: str) -> str:
    """
    Runs the real estate research agent.

    The agent analyzes the investment potential of a given neighborhood
    using a predefined system prompt and returns a structured report
    highlighting positive investment factors and living characteristics.

    Args:
        target_neighborhood (str): Name of the neighborhood to analyze.

    Returns:
        str: Generated research report about the neighborhood.
    """
    system_prompt = load_prompt("researcher_agent_v1")
    response = CLIENT.models.generate_content(
        model = MODEL,
        contents=f"TARGET NEIGHBORHOOD {target_neighborhood}",
        config = types.GenerateContentConfig(
            system_instruction = system_prompt,
            tools=[types.Tool(google_search=types.GoogleSearch())],
            temperature=0.5
        ))
    
    return response.text

# %%
display(Markdown(research_agent("Vila Mariana")))
# Out:
# Olá! A Vila Mariana é um bairro bem interessante de São Paulo para quem pensa em investir em imóveis. Vamos dar uma olhada nos principais pontos que fazem dela uma boa opção:
#
# **1. Visão Geral da Vila Mariana**
#
# A Vila Mariana é conhecida por ser um bairro completo, que oferece uma boa qualidade de vida para seus moradores. É uma região que equilibra áreas residenciais tranquilas com uma infraestrutura comercial e de serviços bem desenvolvida. Além disso, a Vila Mariana tem uma forte ligação com a cultura e a educação, abrigando diversas instituições de ensino e espaços culturais.
#
# **2. Principais Fatores de Valorização**
#
# *   **Localização Estratégica:** A Vila Mariana está localizada em uma região central de São Paulo, com fácil acesso a importantes vias e outros bairros da cidade. Isso facilita a mobilidade dos moradores e aumenta a procura por imóveis na região.
# *   **Infraestrutura Completa:** O bairro oferece uma ampla gama de serviços, como hospitais, escolas, universidades, supermercados e shoppings. Essa infraestrutura completa atrai moradores que buscam praticidade e conveniência no dia a dia.
# *   **Mobilidade:** A Vila Mariana possui diversas estações de metrô, o que facilita o deslocamento para outras regiões da cidade. Além disso, o bairro conta com uma boa oferta de transporte público e ciclofaixas, incentivando o uso de meios de transporte alternativos.
# *   **Gastronomia e Lazer:** A Vila Mariana oferece uma variedade de restaurantes, bares e cafés, além de parques e espaços culturais. Essa diversidade atrai moradores que buscam opções de lazer e entretenimento.
# *   **Qualidade de Vida:** O bairro é considerado um dos mais seguros e arborizados de São Paulo, o que contribui para a qualidade de vida dos moradores. Essa característica atrai famílias e pessoas que buscam um ambiente tranquilo e agradável para morar.
#
# **3. Perfil de Demanda Imobiliária**
#
# A Vila Mariana atrai diferentes perfis de moradores, como estudantes, famílias, jovens profissionais e pessoas da terceira idade. A diversidade de opções de imóveis, desde apartamentos compactos até casas espaçosas, atende às necessidades de cada perfil. A procura por imóveis para locação também é alta, impulsionada pela presença de universidades e empresas na região.
#
# **4. Conclusão sobre o Potencial de Investimento**
#
# A Vila Mariana apresenta um grande potencial de investimento imobiliário devido à sua localização estratégica, infraestrutura completa, mobilidade, qualidade de vida e diversidade de demanda. É um bairro que se valoriza constantemente e oferece boas oportunidades para quem busca investir em imóveis para moradia ou para locação.
#
# Espero que esta análise te ajude a tomar uma decisão mais informada sobre investir na Vila Mariana!
