# %% [markdown]
# ## Chat Metrics

# %% [markdown]
# #### Importing libs

# %%
from pathlib import Path
import sys
sys.path.append(str(Path().resolve().parent))

from agents.planner_agent import planner_agent
from utils.pricing_model_deploy import start_server

start_server()

# %% [markdown]
# #### Testing the prompt

# %%
history = planner_agent(return_object=True)
# Out:
#         <div style="
#             background-color: #D6EAF8;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>USER:</strong><br>
#             <p>Ola!</p>
#         </div>
#         <div style="
#             background-color: #F9E79F;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>AGENT:</strong><br>
#             <p>Olá! Bem-vindo(a) à Quarto. Sou seu consultor imobiliário e estou aqui para ajudar você a explorar as melhores oportunidades de investimento em São Paulo.</p><p>Em quais bairros você tem interesse em investir? Atualmente, sou especialista em:</p><ul><li>Santana</li><li>Mooca</li><li>Brooklin</li><li>Vila Mariana</li><li>Tatuapé</li></ul><p>Posso te ajudar a entender as características de cada um desses bairros e, se desejar, a precificar propriedades neles.</p>
#         </div>
#         <div style="
#             background-color: #D6EAF8;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>USER:</strong><br>
#             <p>Quero precificar em Tatuape. Uma casa de 3 quartos.</p>
#         </div>
#         <div style="
#             background-color: #E5E7E9;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>FUNCTION:</strong><br>
#             <p>🛠 Calling pricing_agent({'info': {'neighborhood': 'Tatuapé', 'bedrooms': 3, 'type': 'Casa'}})</p>
#         </div>
#         <div style="
#             background-color: #F9E79F;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>AGENT:</strong><br>
#             <p>Ótimo! Para prosseguir com a precificação da sua casa de 3 quartos no Tatuapé, preciso de mais algumas informações.</p><p>Quantos banheiros a propriedade possui?</p>
#         </div>
#         <div style="
#             background-color: #D6EAF8;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>USER:</strong><br>
#             <p>2 banheiros e tem 100 metros.</p>
#         </div>
#         <div style="
#             background-color: #E5E7E9;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>FUNCTION:</strong><br>
#             <p>🛠 Calling pricing_agent({'info': {'neighborhood': 'Tatuapé', 'type': 'Casa', 'bathrooms': 2, 'area': 100, 'bedrooms': 3}})</p>
#         </div>
#         <div style="
#             background-color: #F9E79F;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>AGENT:</strong><br>
#             <p>Excelente! Casa de 3 quartos, 2 banheiros e 100 metros quadrados no Tatuapé.</p><p>Agora, para refinar ainda mais a precificação, poderia me informar quantas vagas de garagem a propriedade possui?</p>
#         </div>
#         <div style="
#             background-color: #D6EAF8;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>USER:</strong><br>
#             <p>0 vagas, e nao pago IPTU.</p>
#         </div>
#         <div style="
#             background-color: #E5E7E9;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>FUNCTION:</strong><br>
#             <p>🛠 Calling pricing_agent({'info': {'neighborhood': 'Tatuapé', 'bathrooms': 2, 'type': 'Casa', 'parking_slots': 0, 'area': 100, 'bedrooms': 3, 'iptu': 0}})</p>
#         </div>
#         <div style="
#             background-color: #F9E79F;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>AGENT:</strong><br>
#             <p>Com as informações que você me forneceu, a estimativa de preço para sua casa de 3 quartos, 2 banheiros, 100 metros quadrados, sem vagas de garagem e sem IPTU no Tatuapé é de <strong>R$ 670.173,49</strong>.</p><p>Se tiver mais alguma dúvida ou quiser explorar outras opções, estou à disposição!</p>
#         </div>

# %%
history
# Out:
# {'model_name': 'gemini-2.5-flash',
#  'total_tokens': [1136, 1264, 892, 1312, 1373, 1033, 1514, 1687, 885, 1766],
#  'latency': [2.185721833957359,
#   4.3364255839260295,
#   4.635057540959679,
#   4.5502623750362545],
#  'chat': [{'role': 'user', 'type': 'text', 'content': {'result': 'Ola!'}},
#   {'role': 'planner_agent',
#    'type': 'text',
#    'content': {'result': 'Olá! Bem-vindo(a) à Quarto. Sou seu consultor imobiliário e estou aqui para ajudar você a explorar as melhores oportunidades de investimento em São Paulo.\n\nEm quais bairros você tem interesse em investir? Atualmente, sou especialista em:\n\n*   Santana\n*   Mooca\n*   Brooklin\n*   Vila Mariana\n*   Tatuapé\n\nPosso te ajudar a entender as características de cada um desses bairros e, se desejar, a precificar propriedades neles.'}},
#   {'role': 'user',
#    'type': 'text',
#    'content': {'result': 'Quero precificar em Tatuape. Uma casa de 3 quartos.'}},
#   {'role': 'planner_agent',
#    'type': 'tool_call',
#    'content': {'tool_name': 'pricing_agent',
#     'args': {'info': {'neighborhood': 'Tatuapé',
#       'bedrooms': 3,
#       'type': 'Casa'}}}},
#   {'role': 'pricing_agent',
#    'type': 'tool_response',
#    'content': {'info': {'bedrooms': 3,
#      'bathrooms': None,
#      'parking_slots': None,
#      'area': None,
#      'iptu': None,
#      'neighborhood': 'Tatuapé',
#      'type': 'Casa'},
#     'comment': 'O próximo campo a coletar é bathrooms',
#     'estimated_price': None,
#     'metadata': 892}},
#   {'role': 'planner_agent',
#    'type': 'text',
#    'content': {'result': 'Ótimo! Para prosseguir com a precificação da sua casa de 3 quartos no Tatuapé, preciso de mais algumas informações.\n\nQuantos banheiros a propriedade possui?'}},
#   {'role': 'user',
#    'type': 'text',
#    'content': {'result': '2 banheiros e tem 100 metros.'}},
#   {'role': 'planner_agent',
#    'type': 'tool_call',
#    'content': {'tool_name': 'pricing_agent',
#     'args': {'info': {'neighborhood': 'Tatuapé',
#       'type': 'Casa',
#       'bathrooms': 2,
#       'area': 100,
#       'bedrooms': 3}}}},
#   {'role': 'pricing_agent',
#    'type': 'tool_response',
#    'content': {'info': {'bedrooms': 3,
#      'bathrooms': 2,
#      'parking_slots': None,
#      'area': 100.0,
#      'iptu': None,
#      'neighborhood': 'Tatuapé',
#      'type': 'Casa'},
#     'comment': 'O próximo campo a coletar é parking_slots',
#     'estimated_price': None,
#     'metadata': 1033}},
#   {'role': 'planner_agent',
#    'type': 'text',
#    'content': {'result': 'Excelente! Casa de 3 quartos, 2 banheiros e 100 metros quadrados no Tatuapé.\n\nAgora, para refinar ainda mais a precificação, poderia me informar quantas vagas de garagem a propriedade possui?'}},
#   {'role': 'user',
#    'type': 'text',
#    'content': {'result': '0 vagas, e nao pago IPTU.'}},
#   {'role': 'planner_agent',
#    'type': 'tool_call',
#    'content': {'tool_name': 'pricing_agent',
#     'args': {'info': {'neighborhood': 'Tatuapé',
#       'bathrooms': 2,
#       'type': 'Casa',
#       'parking_slots': 0,
#       'area': 100,
#       'bedrooms': 3,
#       'iptu': 0}}}},
#   {'role': 'pricing_agent',
#    'type': 'tool_response',
#    'content': {'info': {'bedrooms': 3,
#      'bathrooms': 2,
#      'parking_slots': 0,
#      'area': 100.0,
#      'iptu': 0.0,
#      'neighborhood': 'Tatuapé',
#      'type': 'Casa'},
#     'comment': 'Preço estimado com sucesso.',
#     'estimated_price': 670173.49,
#     'metadata': 885}},
#   {'role': 'planner_agent',
#    'type': 'text',
#    'content': {'result': 'Com as informações que você me forneceu, a estimativa de preço para sua casa de 3 quartos, 2 banheiros, 100 metros quadrados, sem vagas de garagem e sem IPTU no Tatuapé é de **R$ 670.173,49**.\n\nSe tiver mais alguma dúvida ou quiser explorar outras opções, estou à disposição!'}}]}
