# %% [markdown]
# ## Chat Metrics

# %% [markdown]
# #### Importing libs

# %%
from pathlib import Path
import sys
sys.path.append(str(Path().resolve().parent))

from agents.planner_agent import planner_agent
from utils.pricing_model_deploy import start_server

start_server()

# %% [markdown]
# #### Testing the prompt

# %%
history = planner_agent(return_object=True)
# Out:
#         <div style="
#             background-color: #D6EAF8;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>USER:</strong><br>
#             <p>Ola!</p>
#         </div>
#         <div style="
#             background-color: #F9E79F;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>AGENT:</strong><br>
#             <p>Olá! Bem-vindo(a) à Quarto. Sou seu consultor imobiliário especializado nos melhores bairros de São Paulo.</p><p>Estou aqui para te ajudar a entender melhor o potencial de investimento em bairros como Santana, Mooca, Brooklin, Vila Mariana e Tatuapé.</p><p>Você tem algum bairro em mente que gostaria de explorar ou precificar uma propriedade?</p>
#         </div>
#         <div style="
#             background-color: #D6EAF8;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>USER:</strong><br>
#             <p>Quero saber como é morar em Tatuape.</p>
#         </div>
#         <div style="
#             background-color: #E5E7E9;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>FUNCTION:</strong><br>
#             <p>🛠 Calling research_agent({'target_neighborhood': 'Tatuapé'})</p>
#         </div>
#         <div style="
#             background-color: #F9E79F;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>AGENT:</strong><br>
#             <p>Que ótima escolha! O Tatuapé é, sem dúvida, um dos bairros mais dinâmicos e cobiçados de São Paulo, e com ótimos motivos para quem pensa em investir ou morar.</p><p><strong>Visão geral do bairro:</strong>O Tatuapé é um bairro com uma história rica na Zona Leste de São Paulo, que soube equilibrar suas raízes tradicionais com uma modernidade pulsante. É um centro urbano completo, oferecendo uma qualidade de vida que atrai diversos perfis.</p><p><strong>Principais fatores de valorização:</strong>*   <strong>Infraestrutura Urbana de Ponta:</strong> O Tatuapé se destaca por sua infraestrutura robusta e completa, com hospitais renomados, escolas de alto nível e universidades.*   <strong>Mobilidade e Acesso Privilegiados:</strong> A localização estratégica do bairro é um grande trunfo, com duas estações de metrô (Tatuapé e Carrão) e acesso às linhas de trem da CPTM, além de um terminal de ônibus e proximidade com vias importantes como a Radial Leste e Marginal Tietê.*   <strong>Comércio e Serviços Diversificados:</strong> O bairro abriga três grandes shoppings – Anália Franco, Metrô Tatuapé e Boulevard Tatuapé – além de uma vasta oferta de comércio de rua, supermercados, farmácias, bancos e uma cena gastronômica e de vida noturna muito agitada.*   <strong>Lazer e Qualidade de Vida:</strong> O Tatuapé oferece diversas opções de lazer e áreas verdes, como os parques do Piqueri e CERET, ideais para atividades ao ar livre.</p><p><strong>Perfil de demanda imobiliária:</strong>O Tatuapé atrai um público diversificado, mas com predominância de famílias de classe média e média-alta, profissionais liberais e investidores. Há uma demanda aquecida tanto para compra quanto para aluguel de imóveis.</p><p><strong>Conclusão sobre o potencial de investimento:</strong>O Tatuapé se consolida como uma das áreas mais promissoras para investimento imobiliário em São Paulo, com um histórico sólido de valorização e uma constante procura por imóveis na região.</p><p>Gostaria de saber mais sobre o potencial de valorização de uma propriedade específica no Tatuapé? Se sim, posso te ajudar a precificar seu imóvel.</p>
#         </div>
#         <div style="
#             background-color: #D6EAF8;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>USER:</strong><br>
#             <p>E quanto custa uma casa la?</p>
#         </div>
#         <div style="
#             background-color: #E5E7E9;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>FUNCTION:</strong><br>
#             <p>🛠 Calling pricing_agent({'info': {'type': 'Casa', 'neighborhood': 'Tatuapé'}})</p>
#         </div>
#         <div style="
#             background-color: #F9E79F;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>AGENT:</strong><br>
#             <p>Para te ajudar a ter uma estimativa de preço mais precisa para uma casa no Tatuapé, preciso de mais algumas informações.</p><p>Quantos quartos tem a casa?</p>
#         </div>
#         <div style="
#             background-color: #D6EAF8;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>USER:</strong><br>
#             <p>2 quartos, 1 banheiro. 0 vagas. 100 de IPTU, 200metros.</p>
#         </div>
#         <div style="
#             background-color: #F9E79F;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>AGENT:</strong><br>
#             <p>Ótimo! Com essas informações, consigo te ajudar a ter uma estimativa mais precisa.</p>
#         </div>
#         <div style="
#             background-color: #E5E7E9;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>FUNCTION:</strong><br>
#             <p>🛠 Calling pricing_agent({'info': {'iptu': 100, 'bedrooms': 2, 'area': 200, 'parking_slots': 0, 'type': 'Casa', 'neighborhood': 'Tatuapé', 'bathrooms': 1}})</p>
#         </div>
#         <div style="
#             background-color: #F9E79F;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>AGENT:</strong><br>
#             <p>Com base nas informações que você me forneceu (2 quartos, 1 banheiro, 0 vagas de garagem, 100 de IPTU e 200 metros quadrados no Tatuapé), a estimativa de preço para essa casa é de <strong>R$ 624.869,02</strong>.</p><p>Lembrando que essa é uma estimativa e o valor final pode variar de acordo com outros fatores específicos da propriedade e do mercado.</p>
#         </div>

# %%
history
# Out:
# {'model_name': 'gemini-2.5-flash',
#  'input_tokens': [1088, 1180, 2289, 2792, 2898, 2959, 3138],
#  'output_tokens': [78, 0, 19, 50, 493, 0, 27, 84, 34, 0, 85, 289, 95, 0],
#  'latency': [2.0203282920410857,
#   17.745820333017036,
#   4.640774917090312,
#   5.659058541990817],
#  'chat': [{'role': 'user', 'type': 'text', 'content': {'result': 'Ola!'}},
#   {'role': 'planner_agent',
#    'type': 'text',
#    'content': {'result': 'Olá! Bem-vindo(a) à Quarto. Sou seu consultor imobiliário especializado nos melhores bairros de São Paulo.\n\nEstou aqui para te ajudar a entender melhor o potencial de investimento em bairros como Santana, Mooca, Brooklin, Vila Mariana e Tatuapé.\n\nVocê tem algum bairro em mente que gostaria de explorar ou precificar uma propriedade?'}},
#   {'role': 'user',
#    'type': 'text',
#    'content': {'result': 'Quero saber como é morar em Tatuape.'}},
#   {'role': 'planner_agent',
#    'type': 'tool_call',
#    'content': {'tool_name': 'research_agent',
#     'args': {'target_neighborhood': 'Tatuapé'}}},
#   {'role': 'research_agent',
#    'type': 'tool_response',
#    'content': {'result': 'Olá! Que excelente escolha para analisarmos. O Tatuapé é, sem dúvida, um dos bairros mais dinâmicos e cobiçados de São Paulo, e com ótimos motivos para quem pensa em investir. Vamos detalhar o que faz dessa região uma aposta tão interessante.\n\n### Visão geral do bairro\n\nO Tatuapé é um bairro com uma história rica na Zona Leste de São Paulo, que soube equilibrar suas raízes tradicionais com uma modernidade pulsante. Começou como uma área de chácaras e fazendas, floresceu com a chegada das indústrias e, hoje, é um centro urbano completo, oferecendo uma qualidade de vida que atrai diversos perfis. É uma região que combina o charme residencial com a conveniência de uma área estratégica da cidade.\n\n### Principais fatores de valorização\n\n1.  **Infraestrutura Urbana de Ponta:** O Tatuapé se destaca por sua infraestrutura robusta e completa. Isso significa uma vasta gama de serviços essenciais como hospitais renomados (Hospital São Luiz Anália Franco, Hospital Tatuapé), escolas de alto nível (Colégio Agostiniano Mendel, Mary Ward, Objetivo Tatuapé) e universidades (UNIP Tatuapé, Fatec Tatuapé), o que atrai famílias e estudantes, garantindo uma demanda constante por imóveis.\n2.  **Mobilidade e Acesso Privilegiados:** A localização estratégica do bairro é um grande trunfo. Com duas estações de metrô (Tatuapé e Carrão, na Linha 3-Vermelha) e acesso às linhas de trem da CPTM (11-Coral e 12-Safira), além de um terminal de ônibus, a região oferece excelente conectividade com o restante da cidade. Para quem se desloca de carro, a proximidade com vias importantes como a Radial Leste, Marginal Tietê e Avenida Salim Farah Maluf facilita o acesso a diversas regiões de São Paulo e até mesmo a rodovias. Essa facilidade de locomoção aumenta significativamente a atratividade para locação e compra.\n3.  **Comércio e Serviços Diversificados:** A oferta comercial e de serviços é um dos pontos mais fortes do Tatuapé. O bairro abriga três grandes shoppings – Anália Franco, Metrô Tatuapé e Boulevard Tatuapé – que são polos de compras, lazer e gastronomia. Além disso, as ruas do Tatuapé são repletas de comércio de rua, supermercados, farmácias, bancos e uma cena gastronômica e de vida noturna muito agitada, com destaque para as ruas Itapura e Coelho Lisboa. Essa autossuficiência do bairro, onde os moradores encontram tudo o que precisam sem grandes deslocamentos, é um fator chave para a valorização imobiliária.\n4.  **Lazer e Qualidade de Vida:** O Tatuapé oferece diversas opções de lazer e áreas verdes, como os parques do Piqueri e CERET, ideais para atividades ao ar livre e momentos de relaxamento. A presença de teatros, cinemas e espaços culturais também enriquece a vida cultural do bairro. Esses atributos contribuem para uma alta qualidade de vida, tornando a região muito desejada para moradia e, consequentemente, para investimento.\n\n### Perfil de demanda imobiliária\n\nO Tatuapé atrai um público diversificado, mas com predominância de famílias de classe média e média-alta, profissionais liberais e investidores que buscam uma infraestrutura completa e a conveniência de ter tudo à mão. Há uma demanda aquecida tanto para compra quanto para aluguel de imóveis, o que é excelente para o investidor. O perfil imobiliário do bairro é bastante variado, com opções que vão desde apartamentos compactos, ideais para jovens profissionais ou casais, até unidades de alto padrão e casas, atendendo a diferentes necessidades e orçamentos. A região tem se destacado por lançamentos de empreendimentos modernos e sofisticados, inclusive de alto padrão.\n\n### Conclusão sobre o potencial de investimento\n\nO Tatuapé se consolida como uma das áreas mais promissoras para investimento imobiliário em São Paulo. O bairro apresenta um histórico sólido de valorização, impulsionado por sua infraestrutura completa, excelente mobilidade, vasta oferta de comércio e serviços, e alta qualidade de vida.\n\nA constante procura por imóveis na região, tant ...
#   {'role': 'planner_agent',
#    'type': 'text',
#    'content': {'result': 'Que ótima escolha! O Tatuapé é, sem dúvida, um dos bairros mais dinâmicos e cobiçados de São Paulo, e com ótimos motivos para quem pensa em investir ou morar.\n\n**Visão geral do bairro:**\nO Tatuapé é um bairro com uma história rica na Zona Leste de São Paulo, que soube equilibrar suas raízes tradicionais com uma modernidade pulsante. É um centro urbano completo, oferecendo uma qualidade de vida que atrai diversos perfis.\n\n**Principais fatores de valorização:**\n*   **Infraestrutura Urbana de Ponta:** O Tatuapé se destaca por sua infraestrutura robusta e completa, com hospitais renomados, escolas de alto nível e universidades.\n*   **Mobilidade e Acesso Privilegiados:** A localização estratégica do bairro é um grande trunfo, com duas estações de metrô (Tatuapé e Carrão) e acesso às linhas de trem da CPTM, além de um terminal de ônibus e proximidade com vias importantes como a Radial Leste e Marginal Tietê.\n*   **Comércio e Serviços Diversificados:** O bairro abriga três grandes shoppings – Anália Franco, Metrô Tatuapé e Boulevard Tatuapé – além de uma vasta oferta de comércio de rua, supermercados, farmácias, bancos e uma cena gastronômica e de vida noturna muito agitada.\n*   **Lazer e Qualidade de Vida:** O Tatuapé oferece diversas opções de lazer e áreas verdes, como os parques do Piqueri e CERET, ideais para atividades ao ar livre.\n\n**Perfil de demanda imobiliária:**\nO Tatuapé atrai um público diversificado, mas com predominância de famílias de classe média e média-alta, profissionais liberais e investidores. Há uma demanda aquecida tanto para compra quanto para aluguel de imóveis.\n\n**Conclusão sobre o potencial de investimento:**\nO Tatuapé se consolida como uma das áreas mais promissoras para investimento imobiliário em São Paulo, com um histórico sólido de valorização e uma constante procura por imóveis na região.\n\nGostaria de saber mais sobre o potencial de valorização de uma propriedade específica no Tatuapé? Se sim, posso te ajudar a precificar seu imóvel.'}},
#   {'role': 'user',
#    'type': 'text',
#    'content': {'result': 'E quanto custa uma casa la?'}},
#   {'role': 'planner_agent',
#    'type': 'tool_call',
#    'content': {'tool_name': 'pricing_agent',
#     'args': {'info': {'type': 'Casa', 'neighborhood': 'Tatuapé'}}}},
#   {'role': 'pricing_agent',
#    'type': 'tool_response',
#    'content': {'info': {'bedrooms': None,
#      'bathrooms': None,
#      'parking_slots': None,
#      'area': None,
#      'iptu': None,
#      'neighborhood': 'Tatuapé',
#      'type': 'Casa'},
#     'comment': 'O próximo campo a coletar é bedrooms',
#     'estimated_price': None}},
#   {'role': 'planner_agent',
#    'type': 'text',
#    'content': {'result': 'Para te ajudar a ter uma estimativa de preço mais precisa para uma casa no Tatuapé, preciso de mais algumas informações.\n\nQuantos quartos tem a casa?'}},
#   {'role': 'user',
#    'type': 'text',
#    'content': {'result': '2 quartos, 1 banheiro. 0 vagas. 100 de IPTU, 200metros.'}},
#   {'role': 'planner_agent',
#    'type': 'text',
#    'content': {'result': 'Ótimo! Com essas informações, consigo te ajudar a ter uma estimativa mais precisa.\n\n'}},
#   {'role': 'planner_agent',
#    'type': 'tool_call',
#    'content': {'tool_name': 'pricing_agent',
#     'args': {'info': {'iptu': 100,
#       'bedrooms': 2,
#       'area': 200,
#       'parking_slots': 0,
#       'type': 'Casa',
#       'neighborhood': 'Tatuapé',
#       'bathrooms': 1}}}},
#   {'role': 'pricing_agent',
#    'type': 'tool_response',
#    'content': {'info': {'bedrooms': 2,
#      'bathrooms': 1,
#      'parking_slots': 0,
#      'area': 200.0,
#      'iptu': 100.0,
#      'neighborhood': 'Tatuapé',
#      'type': 'Casa'},
#     'comment': 'Preço estimado com sucesso.',
#     'estimated_price': 624869.02}},
#   {'role': 'planner_agent',
#    'type': 'text',
#    'content': {'result': 'Com base nas informações que você me forneceu (2 quartos, 1 banheiro, 0 vagas de garagem, 100 de IPTU e 200 metros quadrados no Tatuapé), a estimativa de preço para essa casa é de **R$ 624.869,02**.\n\nLembrando que essa é uma estimativa e o valor final pode variar de acordo com outros fatores específicos da propriedade e do mercado.'}}]}
