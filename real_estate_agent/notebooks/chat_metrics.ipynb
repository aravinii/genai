# %% [markdown]
# ## Chat Metrics

# %% [markdown]
# #### Importing libs

# %%
from pathlib import Path
import sys
sys.path.append(str(Path().resolve().parent))

from agents.planner_agent import planner_agent
from utils.pricing_model_deploy import start_server

start_server()

# %% [markdown]
# #### Testing the prompt

# %%
history = planner_agent(return_object=True)
# Out:
#         <div style="
#             background-color: #D6EAF8;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>USER:</strong><br>
#             <p>Ola!</p>
#         </div>
#         <div style="
#             background-color: #F9E79F;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>AGENT:</strong><br>
#             <p>Olá! Bem-vindo à Quarto. Sou seu consultor imobiliário especializado nos bairros de Santana, Mooca, Brooklin, Vila Mariana e Tatuapé aqui em São Paulo.</p><p>Estou aqui para ajudar você a entender melhor esses bairros e a precificar suas propriedades. Em qual desses bairros você tem interesse em investir ou gostaria de saber mais sobre?</p>
#         </div>
#         <div style="
#             background-color: #D6EAF8;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>USER:</strong><br>
#             <p>Quero morar em Tatuape, como é la?</p>
#         </div>
#         <div style="
#             background-color: #F9E79F;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>AGENT:</strong><br>
#             <p>Ótima escolha! O Tatuapé é um bairro com muitas qualidades. Para te dar uma visão completa, vou acionar nosso agente de pesquisa para detalhar as características, o perfil dos moradores, a infraestrutura, a mobilidade, o comércio e a percepção de valorização.</p><p>Aguarde um momento, por favor.</p>
#         </div>
#         <div style="
#             background-color: #E5E7E9;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>FUNCTION:</strong><br>
#             <p>🛠 Calling research_agent({'target_neighborhood': 'Tatuapé'})</p>
#         </div>
#         <div style="
#             background-color: #F9E79F;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>AGENT:</strong><br>
#             <p>O Tatuapé é realmente um bairro excelente! Nosso agente de pesquisa destacou vários pontos fortes que o tornam uma ótima opção para morar e investir.</p><p>Em resumo, o Tatuapé oferece:</p><ul><li><strong>Infraestrutura Urbana de Ponta:</strong> Com hospitais renomados, escolas e universidades de qualidade.</li><li><strong>Mobilidade e Acesso Privilegiados:</strong> Duas estações de metrô, linhas de trem, terminais de ônibus e acesso fácil a importantes vias como a Radial Leste e Marginal Tietê.</li><li><strong>Comércio e Serviços Diversificados:</strong> Uma vasta gama de lojas, grandes redes e três shoppings centers (Metrô Tatuapé, Boulevard Tatuapé e Anália Franco), além de uma vida noturna agitada na Rua Azevedo Soares.</li><li><strong>Lazer e Qualidade de Vida:</strong> Parques como o Piqueri e o CERET, proporcionando áreas verdes para relaxamento.</li><li><strong>Segurança e Ambiente Acolhedor:</strong> Um bairro percebido como seguro e bem iluminado.</li></ul><p>O perfil de demanda imobiliária é bem diversificado, atraindo famílias, profissionais liberais e investidores, com opções que vão de apartamentos compactos a unidades de alto padrão. A valorização imobiliária tem sido constante, impulsionada por investimentos em infraestrutura e alta demanda.</p><p>Com base nessas informações, você gostaria de saber mais sobre a precificação de alguma propriedade no Tatuapé?</p>
#         </div>

# %%
history
# Out:
# {'model_name': 'gemini-2.5-flash',
#  'total_tokens': [1104, 1209, 3588, 2570],
#  'latency': [2.1402753749862313, 19.403221874963492],
#  'turns': 2,
#  'chat': [{'role': 'user', 'type': 'text', 'content': {'result': 'Ola!'}},
#   {'role': 'planner_agent',
#    'type': 'text',
#    'content': {'result': 'Olá! Bem-vindo à Quarto. Sou seu consultor imobiliário especializado nos bairros de Santana, Mooca, Brooklin, Vila Mariana e Tatuapé aqui em São Paulo.\n\nEstou aqui para ajudar você a entender melhor esses bairros e a precificar suas propriedades. Em qual desses bairros você tem interesse em investir ou gostaria de saber mais sobre?'}},
#   {'role': 'user',
#    'type': 'text',
#    'content': {'result': 'Quero morar em Tatuape, como é la?'}},
#   {'role': 'planner_agent',
#    'type': 'text',
#    'content': {'result': 'Ótima escolha! O Tatuapé é um bairro com muitas qualidades. Para te dar uma visão completa, vou acionar nosso agente de pesquisa para detalhar as características, o perfil dos moradores, a infraestrutura, a mobilidade, o comércio e a percepção de valorização.\n\nAguarde um momento, por favor.\n'}},
#   {'role': 'planner_agent',
#    'type': 'tool_call',
#    'content': {'tool_name': 'research_agent',
#     'args': {'target_neighborhood': 'Tatuapé'}}},
#   {'role': 'research_agent',
#    'type': 'tool_response',
#    'content': {'result': 'Com certeza! O Tatuapé é um bairro que sempre chama a atenção de quem busca boas oportunidades em São Paulo. Vamos dar uma olhada no que faz essa região ser tão interessante para o seu investimento imobiliário.\n\n### Visão geral do bairro\n\nO Tatuapé, localizado na Zona Leste de São Paulo, é um bairro que soube como poucos unir a tradição com a modernidade. Ele se consolidou como uma das regiões mais valorizadas da cidade, oferecendo uma infraestrutura completa e uma atmosfera vibrante. Sua história, que remonta ao período colonial e passou por uma fase industrial, hoje se reflete em um desenvolvimento urbano robusto e uma qualidade de vida elevada.\n\n### Principais fatores de valorização\n\n1.  **Infraestrutura Urbana de Ponta:** O bairro se destaca por sua infraestrutura completa, que abrange desde clínicas médicas e hospitais renomados, como o Hospital São Luiz e o Hospital Vitória, até uma vasta rede de escolas e universidades, como o Colégio Agostiniano Mendel e a UNIP Tatuapé. Essa oferta diversificada de serviços essenciais aumenta a atratividade para famílias e estudantes, garantindo uma demanda constante por imóveis.\n2.  **Mobilidade e Acesso Privilegiados:** A localização estratégica do Tatuapé é um dos seus maiores trunfos. O bairro conta com duas estações de metrô (Tatuapé e Carrão, da Linha 3-Vermelha) e acesso às linhas de trem da CPTM (11-Coral e 12-Safira), além de terminais de ônibus integrados. Essa conectividade facilita o deslocamento para todas as regiões da cidade, incluindo o centro, e para municípios vizinhos, o que é um diferencial enorme para quem busca valorização e liquidez no aluguel. Importantes vias como a Radial Leste, Marginal Tietê e Avenida Salim Farah Maluf também garantem fácil acesso de carro.\n3.  **Comércio e Serviços Diversificados:** O Tatuapé é um verdadeiro polo comercial e de serviços. A região oferece uma mistura interessante de comércio de rua, com lojas e grandes redes, e três grandes shoppings centers: Shopping Metrô Tatuapé, Shopping Boulevard Tatuapé e Shopping Anália Franco. Essa variedade atende a todas as necessidades e desejos, desde compras até entretenimento e gastronomia. A forte oferta gastronômica, com diversas opções de bares e restaurantes, inclusive na agitada Rua Azevedo Soares, torna a região muito atraente para locação, especialmente para um público que valoriza a vida noturna e o lazer.\n4.  **Lazer e Qualidade de Vida:** Para quem busca um equilíbrio entre a agitação urbana e momentos de relaxamento, o Tatuapé oferece áreas verdes como o Parque do Piqueri e o CERET. A presença desses espaços contribui para a qualidade de vida dos moradores, tornando os imóveis na região mais desejados.\n5.  **Segurança e Ambiente Acolhedor:** O bairro é percebido como seguro, com ruas bem iluminadas, o que é um fator importante para a decisão de moradia e, consequentemente, para a demanda imobiliária.\n\n### Perfil de demanda imobiliária\n\nO Tatuapé atrai um perfil de moradores bastante diversificado, incluindo famílias de classe média e média-alta, profissionais liberais e investidores. Essa variedade se reflete no mercado imobiliário local, que oferece desde apartamentos compactos e studios, ideais para solteiros ou casais jovens, até unidades de alto padrão com 3 ou 4 dormitórios e coberturas, que atraem um público mais exigente.\n\nA demanda por imóveis no Tatuapé é consistentemente alta, sendo um dos bairros mais procurados para compra e aluguel em São Paulo. Essa procura aquecida, inclusive para imóveis de alto padrão como apartamentos na cobertura, indica um mercado imobiliário dinâmico e com grande potencial de liquidez.\n\n### Conclusão sobre o potencial de investimento\n\nO Tatuapé se consolida como uma escolha estratégica e muito promissora para investimento imobiliário. A combinação de uma infraestrutura urbana completa, excelente mobilidade com diversas opções de transporte público, um comércio e serviços robustos, além de opções de  ...
#   {'role': 'planner_agent',
#    'type': 'text',
#    'content': {'result': 'O Tatuapé é realmente um bairro excelente! Nosso agente de pesquisa destacou vários pontos fortes que o tornam uma ótima opção para morar e investir.\n\nEm resumo, o Tatuapé oferece:\n\n*   **Infraestrutura Urbana de Ponta:** Com hospitais renomados, escolas e universidades de qualidade.\n*   **Mobilidade e Acesso Privilegiados:** Duas estações de metrô, linhas de trem, terminais de ônibus e acesso fácil a importantes vias como a Radial Leste e Marginal Tietê.\n*   **Comércio e Serviços Diversificados:** Uma vasta gama de lojas, grandes redes e três shoppings centers (Metrô Tatuapé, Boulevard Tatuapé e Anália Franco), além de uma vida noturna agitada na Rua Azevedo Soares.\n*   **Lazer e Qualidade de Vida:** Parques como o Piqueri e o CERET, proporcionando áreas verdes para relaxamento.\n*   **Segurança e Ambiente Acolhedor:** Um bairro percebido como seguro e bem iluminado.\n\nO perfil de demanda imobiliária é bem diversificado, atraindo famílias, profissionais liberais e investidores, com opções que vão de apartamentos compactos a unidades de alto padrão. A valorização imobiliária tem sido constante, impulsionada por investimentos em infraestrutura e alta demanda.\n\nCom base nessas informações, você gostaria de saber mais sobre a precificação de alguma propriedade no Tatuapé?'}}]}
