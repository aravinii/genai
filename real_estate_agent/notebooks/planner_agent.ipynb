# %% [markdown]
# ## Planner Agent
#
# Folder docs: [evals/README.md](../evals/README.md) (conversation capture and metrics).

# %% [markdown]
# #### Importing libs

# %%
from pathlib import Path
import sys
sys.path.append(str(Path().resolve().parent))

from agents.planner_agent import planner_agent
from utils.pricing_model_deploy import start_server

start_server()

# %% [markdown]
# #### Testing the prompt

# %%
planner_agent()
# Out:
#         <div style="
#             background-color: #D6EAF8;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>USER:</strong><br>
#             <p>Ola!</p>
#         </div>
#         <div style="
#             background-color: #F9E79F;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>AGENT:</strong><br>
#             <p>Olá! Bem-vindo(a) à Quarto. Sou seu consultor imobiliário especializado em algumas das melhores regiões de São Paulo.</p><p>Para começarmos, em qual bairro você tem interesse em investir ou gostaria de precificar uma propriedade? Meus bairros de especialização são Santana, Mooca, Brooklin, Vila Mariana e Tatuapé.</p>
#         </div>
#         <div style="
#             background-color: #D6EAF8;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>USER:</strong><br>
#             <p>Eu quero saber mais sobre Tatuape.</p>
#         </div>
#         <div style="
#             background-color: #F9E79F;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>AGENT:</strong><br>
#             <p>Ótima escolha! O Tatuapé é um bairro com grande potencial.</p><p>Vou acionar nosso agente de pesquisa para trazer as informações mais relevantes sobre as características, infraestrutura e o perfil de moradores do Tatuapé. Assim, você terá uma visão completa do bairro.</p><p>Só um momento, por favor.</p>
#         </div>
#         <div style="
#             background-color: #E5E7E9;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>FUNCTION:</strong><br>
#             <p>🛠 Calling research_agent({'target_neighborhood': 'Tatuapé'})</p>
#         </div>
#         <div style="
#             background-color: #F9E79F;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>AGENT:</strong><br>
#             <p>O Tatuapé é realmente um bairro com características muito interessantes para quem busca investir!</p><p>Nosso agente de pesquisa destacou pontos como a <strong>infraestrutura urbana de ponta</strong>, com hospitais, escolas e diversas opções de lazer. A <strong>mobilidade e acesso privilegiados</strong> também são um grande diferencial, com fácil acesso a importantes vias e estações de metrô e CPTM.</p><p>Além disso, o <strong>comércio e serviços diversificados</strong>, com shoppings e ruas comerciais, e as <strong>opções de lazer e qualidade de vida</strong>, com parques e uma gastronomia rica, tornam o Tatuapé um local muito cobiçado.</p><p>O perfil de demanda imobiliária é sólido e diversificado, atraindo famílias, jovens casais e solteiros, o que contribui para um <strong>excelente potencial de investimento imobiliário</strong> e valorização constante.</p><p>Com todas essas informações, você gostaria de saber mais sobre a precificação de alguma propriedade no Tatuapé?</p>
#         </div>
