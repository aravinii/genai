# %% [markdown]
# ## Research Agent

# %% [markdown]
# #### Importing libs

# %%
from google import genai
from google.genai import types
from IPython.display import display, Markdown, HTML

import os
from pathlib import Path
import sys
sys.path.append(str(Path().resolve().parent))
from utils.config import CLIENT, MODEL

# %% [markdown]
# #### Defining auxiliary functions

# %%
def load_prompt(prompt_name: str) -> str:
    """
    Load a prompt from the prompts directory.
    """
    base_dir = Path.cwd().parent
    prompt_path = base_dir / "prompts" / f"{prompt_name}.txt"

    if not prompt_path.exists():
        raise FileNotFoundError(f"Prompt {prompt_name} not found")

    with open(prompt_path, "r", encoding="utf-8") as f:
        return f.read()

# %% [markdown]
# #### Prompt Engineering

# %%
def research_agent(target_neighborhood: str) -> str:
    """
    Runs the real estate research agent.

    The agent analyzes the investment potential of a given neighborhood
    using a predefined system prompt and returns a structured report
    highlighting positive investment factors and living characteristics.

    Args:
        target_neighborhood (str): Name of the neighborhood to analyze.

    Returns:
        str: Generated research report about the neighborhood.
    """
    system_prompt = load_prompt("research_agent_v1")
    response = CLIENT.models.generate_content(
        model = MODEL,
        contents=f"TARGET NEIGHBORHOOD {target_neighborhood}",
        config = types.GenerateContentConfig(
            system_instruction = system_prompt,
            tools=[types.Tool(google_search=types.GoogleSearch())],
            temperature=0.5
        ))
    
    return response.text

# %% [markdown]
# #### Testing the prompt

# %%
display(Markdown(research_agent("Vila Mariana")))
# Out:
# Olá! Que bom que você está de olho na Vila Mariana. É um bairro que realmente chama a atenção de quem busca um investimento imobiliário sólido e com grande potencial. Vamos dar uma olhada no que faz dessa região uma excelente aposta.
#
# ### 1. Visão geral do bairro
#
# A Vila Mariana é um dos bairros mais charmosos e tradicionais da Zona Sul de São Paulo, conhecido por ser um local que equilibra a tranquilidade de ruas arborizadas com a efervescência de uma vida urbana completa. É um bairro com uma história rica e uma infraestrutura que atrai moradores de diversos perfis, combinando edificações comerciais e residenciais. Sua localização estratégica, próxima a regiões importantes como o Paraíso, Moema e Ibirapuera, e com fácil acesso ao centro expandido, é um dos seus grandes diferenciais.
#
# ### 2. Principais fatores de valorização
#
# A valorização imobiliária na Vila Mariana não é por acaso; ela é impulsionada por uma série de fatores que a tornam um endereço altamente desejado:
#
# *   **Infraestrutura Urbana Completa:** O bairro oferece uma infraestrutura consolidada e diversificada. Você encontra de tudo para o dia a dia sem precisar se deslocar muito, desde supermercados de grandes redes e farmácias 24h até agências bancárias e academias. Essa conveniência de ter serviços essenciais a poucos minutos de casa aumenta a atratividade para locação e compra.
# *   **Mobilidade e Acesso Privilegiados:** A Vila Mariana se destaca pela excelente mobilidade urbana. O bairro é muito bem servido por transporte público, com diversas estações de metrô (Linha 1-Azul: Ana Rosa, Vila Mariana; Linha 2-Verde: Ana Rosa, Paraíso, Chácara Klabin; Linha 5-Lilás: Chácara Klabin), além de várias linhas de ônibus. Isso garante fácil acesso a importantes polos empresariais como a Avenida Paulista, Faria Lima e Berrini, e a outras regiões da cidade, o que é um grande atrativo para quem busca otimizar o tempo de deslocamento. Há também uma boa distribuição de ciclovias, incentivando um estilo de vida mais ativo e sustentável.
# *   **Educação de Alto Nível:** A presença de instituições de ensino renomadas, como a ESPM, Belas Artes, Escola Paulista de Medicina (UNIFESP) e colégios de destaque como o Bandeirantes e o Marista Arquidiocesano, atrai famílias e estudantes, gerando uma demanda constante por imóveis na região.
