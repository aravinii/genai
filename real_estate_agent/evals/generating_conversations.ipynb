# %% [markdown]
# ## Chat Metrics

# %% [markdown]
# #### Importing libs

# %%
from pathlib import Path
import sys
sys.path.append(str(Path().resolve().parent))

from agents.planner_agent import planner_agent
from utils.pricing_model_deploy import start_server

start_server()
# Out:
# <Thread(Thread-4 (_run), started daemon 6262550528)>

# %% [markdown]
# #### Testing the prompt

# %%
#all_conversations = [] #firt time create the list
history = planner_agent(return_object=True)
# Out:
#         <div style="
#             background-color: #D6EAF8;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>USER:</strong><br>
#             <p>Ola!</p>
#         </div>
#         <div style="
#             background-color: #F9E79F;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>AGENT:</strong><br>
#             <p>Olá! Bem-vindo à Quarto. Sou seu consultor imobiliário especializado nos bairros de Santana, Mooca, Brooklin, Vila Mariana e Tatuapé aqui em São Paulo.</p><p>Estou aqui para te ajudar a entender melhor esses bairros e a precificar suas propriedades. Em qual desses bairros você tem interesse em investir ou gostaria de saber mais sobre?</p>
#         </div>
#         <div style="
#             background-color: #D6EAF8;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>USER:</strong><br>
#             <p>Me conta sobre Tatuapé? Tem muita casa la?</p>
#         </div>
#         <div style="
#             background-color: #E5E7E9;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>FUNCTION:</strong><br>
#             <p>🛠 Calling research_agent({'target_neighborhood': 'Tatuapé'})</p>
#         </div>
#         <div style="
#             background-color: #F9E79F;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>AGENT:</strong><br>
#             <p>O Tatuapé é um bairro com uma infraestrutura muito completa e consolidada, o que o torna bastante atrativo para investimentos. Ele oferece uma excelente mobilidade, com estações de metrô e CPTM, além de um comércio e serviços bem diversificados, incluindo shoppings e uma vida noturna agitada.</p><p>Sobre a sua pergunta se tem muita casa lá, o Tatuapé tem uma diversidade de propriedades. Embora seja um bairro em constante verticalização, com muitos apartamentos e novos empreendimentos, ainda é possível encontrar casas, especialmente em algumas áreas mais tradicionais. O perfil de demanda é bem diversificado, atraindo desde famílias até jovens profissionais.</p><p>Gostaria de explorar mais alguma característica do Tatuapé ou de outro bairro? Ou talvez você tenha interesse em saber sobre a precificação de alguma propriedade?</p>
#         </div>
#         <div style="
#             background-color: #D6EAF8;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>USER:</strong><br>
#             <p>E vale a pena investir la? Me conta mais sobre o bairro.</p>
#         </div>
#         <div style="
#             background-color: #F9E79F;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>AGENT:</strong><br>
#             <p>Sim, o Tatuapé é considerado um dos bairros mais valorizados de São Paulo e tem demonstrado um histórico de alta valorização, com imóveis de alto padrão apresentando crescimentos expressivos. A combinação de infraestrutura urbana completa, excelente mobilidade, comércio e serviços diversificados, e um perfil de moradores com alto poder aquisitivo, cria um ambiente de valorização constante e sólida.</p><p>Além disso, o bairro tem sido um polo de lançamentos imobiliários e vendas de imóveis novos, indicando um mercado aquecido e com grande potencial de retorno no médio e longo prazo. Investir no Tatuapé é apostar em um bairro que oferece qualidade de vida e conveniência, fatores que impulsionam a demanda e garantem uma excelente rentabilidade para o seu capital.</p><p>Você gostaria de saber mais sobre algum aspecto específico do Tatuapé, como o perfil dos moradores, opções de lazer, ou talvez já queira ter uma ideia de preço para alguma propriedade na região?</p>
#         </div>
#         <div style="
#             background-color: #D6EAF8;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>USER:</strong><br>
#             <p>Obrigado.</p>
#         </div>
#         <div style="
#             background-color: #F9E79F;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>AGENT:</strong><br>
#             <p>De nada! Fico feliz em ajudar.</p><p>Se surgir mais alguma dúvida sobre o Tatuapé, ou se você quiser explorar outros bairros como Santana, Mooca, Brooklin ou Vila Mariana, é só me dizer.</p><p>E se em algum momento você tiver interesse em precificar uma propriedade, me avise! Posso acionar nosso especialista em precificação para te ajudar com isso.</p>
#         </div>

# %%
all_conversations.append(history) #save all history conversations here, executing the code above multiple times

# %%
out_path = Path("/Users/vinicius.araujo/Github/genai/data") / "conversations.json"
out_path.write_text(json.dumps(all_conversations, ensure_ascii=False, indent=2), encoding="utf-8")
# Out:
# 55966
