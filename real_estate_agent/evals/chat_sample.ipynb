# %% [markdown]
# ## Chat sample
#
# Capture multi-turn runs with the **planner** (and pricing server) and export JSON for [evals](README.md) (`chat_evals`, `chat_metrics`).

# %% [markdown]
# #### Importing libs

# %%
from pathlib import Path
import sys
import json
sys.path.append(str(Path().resolve().parent))

from agents.planner_agent import planner_agent
from utils.pricing_model_deploy import start_server

start_server()

# %% [markdown]
# #### Testing the prompt

# %%
#all_conversations = [] #firt time create the list
history = planner_agent(return_object=True, rag=True)
# Out:
#         <div style="
#             background-color: #D6EAF8;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>USER:</strong><br>
#             <p>Ola</p>
#         </div>
#         <div style="
#             background-color: #F9E79F;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>AGENT:</strong><br>
#             <p>Olá! Bem-vindo à Quarto. Sou seu consultor imobiliário especializado nos bairros de Santana, Mooca, Brooklin, Vila Mariana e Tatuapé aqui em São Paulo.</p><p>Estou aqui para te ajudar a entender melhor o potencial de investimento e precificação de propriedades nesses bairros. Para começarmos, em qual desses bairros você tem interesse em investir ou precificar uma propriedade?</p>
#         </div>
#         <div style="
#             background-color: #D6EAF8;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>USER:</strong><br>
#             <p>Me conta sobre Tatuapé? Tem muita casa la?</p>
#         </div>
#         <div style="
#             background-color: #E5E7E9;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>FUNCTION:</strong><br>
#             <p>🛠 Calling rag_agent({'target_neighborhood': 'Tatuapé'})</p>
#         </div>
#         <div style="
#             background-color: #F9E79F;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>AGENT:</strong><br>
#             <p>O Tatuapé é um bairro com uma infraestrutura urbana muito completa e em constante desenvolvimento, o que o torna bastante procurado. Historicamente, ele tem se modernizado com a chegada de muitos empreendimentos, especialmente apartamentos em condomínios com diversas opções de lazer.</p><p>Embora existam casas no bairro, o perfil de novos lançamentos e a demanda atual se concentram mais em apartamentos, que atendem a um público diversificado, desde jovens profissionais a famílias.</p><p>Gostaria de explorar mais a fundo as características do Tatuapé ou talvez já esteja interessado em saber como podemos precificar uma propriedade por lá?</p>
#         </div>
#         <div style="
#             background-color: #D6EAF8;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>USER:</strong><br>
#             <p>E vale a pena investir la? Me conta mais sobre o bairro.</p>
#         </div>
#         <div style="
#             background-color: #F9E79F;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>AGENT:</strong><br>
#             <p>Sim, o Tatuapé é considerado uma excelente oportunidade de investimento imobiliário!</p><p>Ele se destaca por diversos fatores:</p><ul><li><strong>Potencial de Valorização Consistente:</strong> O Tatuapé tem apresentado uma valorização imobiliária acima da média em São Paulo, sendo um dos bairros mais cobiçados para morar e investir.</li><li><strong>Mobilidade e Acesso Estratégicos:</strong> A localização é um grande diferencial, com acesso facilitado a importantes vias como a Radial Leste e Marginal Tietê, além de ser um hub de transporte público com estações de metrô (Tatuapé e Carrão) e CPTM, e um terminal de ônibus.</li><li><strong>Infraestrutura Urbana Completa:</strong> O bairro oferece uma rede robusta de comércio e serviços, incluindo grandes shoppings (Anália Franco, Metrô Tatuapé), supermercados, academias, hospitais renomados, escolas de qualidade e parques.</li><li><strong>Comércio e Serviços Diversificados:</strong> Há uma vasta oferta gastronômica, vida noturna agitada, e uma grande concentração de serviços essenciais, além de um polo empresarial.</li><li><strong>Perfil de Demanda Imobiliária:</strong> Atrai um público diversificado, incluindo famílias, jovens profissionais e casais, muitos com alto poder aquisitivo, buscando imóveis de qualidade.</li></ul><p>Em resumo, o Tatuapé oferece uma combinação de infraestrutura completa, mobilidade eficiente, comércio diversificado e um perfil de moradores com alto poder aquisitivo, criando um ambiente propício para a valorização constante dos imóveis. É um bairro com solidez, rentabilidade e um futuro promissor para investimentos.</p><p>Você tem alguma propriedade no Tatuapé que gostaria de precificar, ou gostaria de explorar outro bairro?</p>
#         </div>
#         <div style="
#             background-color: #D6EAF8;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>USER:</strong><br>
#             <p>Obrigado</p>
#         </div>
#         <div style="
#             background-color: #F9E79F;
#             color: black;
#             padding: 10px;
#             border-radius: 8px;
#             margin: 5px 0px;
#             font-family: Arial, sans-serif;
#         ">
#             <strong>AGENT:</strong><br>
#             <p>De nada! Fico feliz em ajudar.</p><p>Se surgir alguma outra dúvida sobre o Tatuapé, ou se você quiser explorar as características de Santana, Mooca, Brooklin ou Vila Mariana, é só me dizer.</p><p>E se em algum momento você tiver interesse em precificar uma propriedade em um desses bairros, me avise! Posso acionar nosso especialista em precificação para te ajudar com isso.</p>
#         </div>

# %%
#all_conversations.append(history) #save all history conversations here, executing the code above multiple times

# %%
#out_path = Path("/Users/vinicius.araujo/Github/genai/data") / "conversations_v2.json"
#out_path.write_text(json.dumps(all_conversations, ensure_ascii=False, indent=2), encoding="utf-8")
# Out:
# 57003
